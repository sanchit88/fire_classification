# %% [markdown]
# ### Custom Shallow Network - miniVGG
# With batch normalization and (optional) random cropping of the image

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext tensorboard

# %%
import os
import numpy as np
from glob import glob
from tqdm import tqdm
import datetime
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, TensorBoard
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
# dimensions of our images.
img_width, img_height = 224, 224
train_data_dir = '/home/sanchit/Documents/Projects/datasets/fire_and_smoke_data/train/'
validation_data_dir = '/home/sanchit/Documents/Projects/datasets/fire_and_smoke_data/val/'
nb_train_samples = 2400
nb_validation_samples = 490
epochs = 100
batch_size = 32
model_path = "./models/cust_network.h5"
init_lr = 0.003

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
model = Sequential()
input_shape = (img_width, img_height, 3)
model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(32, (3, 3), padding='same', strides=2, kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(32, (3, 3), padding='same', strides=2, kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(32, (3, 3), padding='same', kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(64, (3, 3), padding='same', strides=2, kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(64, (3, 3), padding='same', kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(64, (3, 3), padding='same', strides=2, kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(128, (3, 3), padding='same', kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(Conv2D(128, (3, 3), padding='same', strides=2, kernel_initializer='he_normal', 
                 kernel_regularizer=l2(1e-4), input_shape=input_shape))
model.add(BatchNormalization())
model.add(Activation('relu'))

model.add(GlobalAveragePooling2D())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 32)      896
# _________________________________________________________________
# batch_normalization (BatchNo (None, 224, 224, 32)      128
# _________________________________________________________________
# activation (Activation)      (None, 224, 224, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 112, 112, 32)      128
# _________________________________________________________________
# activation_1 (Activation)    (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 32)      9248
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 112, 112, 32)      128
# _________________________________________________________________
# activation_2 (Activation)    (None, 112, 112, 32)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 32)        9248
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 56, 56, 32)        128
# _________________________________________________________________
# activation_3 (Activation)    (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 32)        9248
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 56, 56, 32)        128
# _________________________________________________________________
# activation_4 (Activation)    (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 28, 28, 64)        18496
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# activation_5 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 14, 14, 64)        256
# _________________________________________________________________
# activation_7 (Activation)    (None, 14, 14, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 14, 14, 128)       73856
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# activation_8 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 7, 7, 128)         147584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# activation_9 (Activation)    (None, 7, 7, 128)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8256
# _________________________________________________________________
# activation_10 (Activation)   (None, 64)                0
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_11 (Activation)   (None, 1)                 0
# =================================================================
# Total params: 362,433
# Trainable params: 361,217
# Non-trainable params: 1,216
# _________________________________________________________________

# %%
#opt = SGD(lr=init_lr, momentum=0.9) # 93.33%
#opt = SGD(lr=init_lr, momentum=0.9, decay=init_lr) # 88.96 %
#opt = Adam() # 94.17 %
#opt = RMSprop() #  %
opt = SGD()
#opt = Adam(learning_rate=init_lr) # 93.12 %

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %%
def load_data(dir_path="", class_mode='binary', classes=None):
    """
    loads all the images for all the classes (sub-dirs) provided in the input directory.
    :param dir_path -  input directory which contains for each class a sub-directory. 
    :param class_mode - binary (for usage in binary_crossentropy loss) and categorical (categorical_crossentropy loss)
    :params classes - a list of classes'names 
    """
    X = []
    y = []
    data_kind = dir_path.split("/")[-2] # either training or validation or testing
    directories=[d for d in os.listdir(dir_path) if os.path.isdir(d) or (not d.startswith("."))]
    
    for label, class_name in enumerate(directories):
        print(f"loading {data_kind} data for class: {class_name}")
        class_dir = os.path.join(dir_path, class_name)
        for img_path in tqdm(glob(class_dir + '/*.jpg')):
            img = load_img(img_path, target_size=(img_width, img_height))
            img = img_to_array(img)

            # save the image and its corresponding label
            X.append(img)
            y.append(label)
                
    X = np.asarray(X, dtype=np.float32) / 255.0
    y = np.asarray(y)
    
    if class_mode == "categorical":
        y = to_categorical(y_train, num_classes=classes)
        
    print(f"total number of images loaded: {X.shape[0]} and of shape: {X.shape[1:]}")
    
    return X, y

# %%
X_train, y_train = load_data(dir_path=train_data_dir)
X_val, y_val = load_data(dir_path=validation_data_dir)
# Out:
#   0%|          | 0/1200 [00:00<?, ?it/s]
# loading train data for class: fire
#  35%|███▍      | 418/1200 [00:03<00:06, 130.03it/s]/home/sanchit/miniconda3/envs/tf2.1/lib/python3.7/site-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 100%|██████████| 1200/1200 [00:09<00:00, 130.34it/s]
#   2%|▏         | 21/1200 [00:00<00:05, 196.88it/s]
# loading train data for class: no_fire
# 100%|██████████| 1200/1200 [00:09<00:00, 133.02it/s]
#   3%|▎         | 7/245 [00:00<00:06, 37.92it/s]
# total number of images loaded: 2400 and of shape: (224, 224, 3)
# loading val data for class: fire
# 100%|██████████| 245/245 [00:03<00:00, 73.22it/s]
#  12%|█▏        | 30/245 [00:00<00:00, 292.88it/s]
# loading val data for class: no_fire
# 100%|██████████| 245/245 [00:01<00:00, 144.76it/s]
# total number of images loaded: 490 and of shape: (224, 224, 3)

# %%
# create a train generator
train_datagen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True, 
    vertical_flip=True,
    rotation_range=30,
    fill_mode="wrap",
    height_shift_range=0.15,
    width_shift_range=0.15)

# create a test/val generator
test_datagen = ImageDataGenerator()

# %%
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size, shuffle=True)
validation_generator = test_datagen.flow(X_val, y_val, batch_size=batch_size, shuffle=False)

# %%
# define callbacks before starting the training
# early_stop = EarlyStopping(monitor="val_loss", patience=10, mode="min", verbose=1)
# model_checkpoint = ModelCheckpoint(model_path, monitor="val_accuracy", save_best_only=True, mode='max', verbose=1)
# logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
# tensorboard = TensorBoard(log_dir=logdir, histogram_freq=1)
# callbacks = [early_stop, model_checkpoint, tensorboard]

H = model.fit_generator(train_generator, 
                        steps_per_epoch=nb_train_samples // batch_size, 
                        epochs=epochs,
                        validation_data=validation_generator,
                        validation_steps=nb_validation_samples // batch_size, 
                        workers = 8)

# launch TensorBoard
#%tensorboard --logdir logs
# Out:
# WARNING:tensorflow:From <ipython-input-11-da5183aa35ef>:13: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 75 steps, validate for 15 steps
# Epoch 1/100
# 75/75 [==============================] - 6s 84ms/step - loss: 0.7606 - accuracy: 0.6350 - val_loss: 0.7841 - val_accuracy: 0.6542
# Epoch 2/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.6723 - accuracy: 0.7158 - val_loss: 0.7740 - val_accuracy: 0.5729
# Epoch 3/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.6462 - accuracy: 0.7346 - val_loss: 0.7778 - val_accuracy: 0.6125
# Epoch 4/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.6262 - accuracy: 0.7538 - val_loss: 0.7163 - val_accuracy: 0.7021
# Epoch 5/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.6144 - accuracy: 0.7550 - val_loss: 0.6861 - val_accuracy: 0.7250
# Epoch 6/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.6079 - accuracy: 0.7675 - val_loss: 0.6414 - val_accuracy: 0.7292
# Epoch 7/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.5947 - accuracy: 0.7771 - val_loss: 0.6459 - val_accuracy: 0.7312
# Epoch 8/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.5907 - accuracy: 0.7883 - val_loss: 0.6069 - val_accuracy: 0.7708
# Epoch 9/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.5748 - accuracy: 0.7858 - val_loss: 0.5909 - val_accuracy: 0.7750
# Epoch 10/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.5656 - accuracy: 0.7950 - val_loss: 0.5957 - val_accuracy: 0.7542
# Epoch 11/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.5497 - accuracy: 0.8062 - val_loss: 0.7187 - val_accuracy: 0.7229
# Epoch 12/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.5552 - accuracy: 0.8092 - val_loss: 0.6475 - val_accuracy: 0.7667
# Epoch 13/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.5383 - accuracy: 0.8158 - val_loss: 0.5741 - val_accuracy: 0.7896
# Epoch 14/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.5313 - accuracy: 0.8200 - val_loss: 0.5760 - val_accuracy: 0.7771
# Epoch 15/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.5230 - accuracy: 0.8225 - val_loss: 0.5421 - val_accuracy: 0.8208
# Epoch 16/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.5160 - accuracy: 0.8417 - val_loss: 0.5140 - val_accuracy: 0.8313
# Epoch 17/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.5005 - accuracy: 0.8367 - val_loss: 0.5147 - val_accuracy: 0.8250
# Epoch 18/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.4957 - accuracy: 0.8346 - val_loss: 0.5419 - val_accuracy: 0.8208
# Epoch 19/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.4903 - accuracy: 0.8433 - val_loss: 0.4833 - val_accuracy: 0.8292
# Epoch 20/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4908 - accuracy: 0.8471 - val_loss: 0.5130 - val_accuracy: 0.8208
# Epoch 21/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4844 - accuracy: 0.8442 - val_loss: 0.5727 - val_accuracy: 0.8292
# Epoch 22/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.4774 - accuracy: 0.8392 - val_loss: 0.5288 - val_accuracy: 0.8167
# Epoch 23/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4722 - accuracy: 0.8483 - val_loss: 0.4768 - val_accuracy: 0.8417
# Epoch 24/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.4727 - accuracy: 0.8458 - val_loss: 0.5159 - val_accuracy: 0.8125
# Epoch 25/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4705 - accuracy: 0.8550 - val_loss: 0.4989 - val_accuracy: 0.8292
# Epoch 26/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.4706 - accuracy: 0.8537 - val_loss: 0.4506 - val_accuracy: 0.8667
# Epoch 27/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4653 - accuracy: 0.8533 - val_loss: 0.4896 - val_accuracy: 0.8229
# Epoch 28/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4596 - accuracy: 0.8546 - val_loss: 0.4629 - val_accuracy: 0.8500
# Epoch 29/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4560 - accuracy: 0.8542 - val_loss: 0.4925 - val_accuracy: 0.8604
# Epoch 30/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4569 - accuracy: 0.8612 - val_loss: 0.4688 - val_accuracy: 0.8542
# Epoch 31/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4422 - accuracy: 0.8692 - val_loss: 0.4955 - val_accuracy: 0.8354
# Epoch 32/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.4407 - accuracy: 0.8662 - val_loss: 0.4486 - val_accuracy: 0.8583
# Epoch 33/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4364 - accuracy: 0.8717 - val_loss: 0.4585 - val_accuracy: 0.8479
# Epoch 34/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.4326 - accuracy: 0.8771 - val_loss: 0.4763 - val_accuracy: 0.8500
# Epoch 35/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4332 - accuracy: 0.8746 - val_loss: 0.4450 - val_accuracy: 0.8646
# Epoch 36/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4263 - accuracy: 0.8763 - val_loss: 0.4592 - val_accuracy: 0.8583
# Epoch 37/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4358 - accuracy: 0.8737 - val_loss: 0.4819 - val_accuracy: 0.8500
# Epoch 38/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4311 - accuracy: 0.8775 - val_loss: 0.5196 - val_accuracy: 0.8167
# Epoch 39/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4173 - accuracy: 0.8742 - val_loss: 0.4401 - val_accuracy: 0.8583
# Epoch 40/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4160 - accuracy: 0.8800 - val_loss: 0.5500 - val_accuracy: 0.8313
# Epoch 41/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4284 - accuracy: 0.8771 - val_loss: 0.4319 - val_accuracy: 0.8646
# Epoch 42/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.4265 - accuracy: 0.8779 - val_loss: 0.4547 - val_accuracy: 0.8542
# Epoch 43/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4154 - accuracy: 0.8813 - val_loss: 0.4450 - val_accuracy: 0.8667
# Epoch 44/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4178 - accuracy: 0.8763 - val_loss: 0.4335 - val_accuracy: 0.8646
# Epoch 45/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.4050 - accuracy: 0.8917 - val_loss: 0.4244 - val_accuracy: 0.8854
# Epoch 46/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4039 - accuracy: 0.8875 - val_loss: 0.4388 - val_accuracy: 0.8646
# Epoch 47/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4035 - accuracy: 0.8888 - val_loss: 0.4544 - val_accuracy: 0.8521
# Epoch 48/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.4131 - accuracy: 0.8825 - val_loss: 0.4902 - val_accuracy: 0.8375
# Epoch 49/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4032 - accuracy: 0.8933 - val_loss: 0.4707 - val_accuracy: 0.8500
# Epoch 50/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.4052 - accuracy: 0.8921 - val_loss: 0.4552 - val_accuracy: 0.8646
# Epoch 51/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3990 - accuracy: 0.8900 - val_loss: 0.4822 - val_accuracy: 0.8521
# Epoch 52/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3772 - accuracy: 0.8975 - val_loss: 0.4125 - val_accuracy: 0.8708
# Epoch 53/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3888 - accuracy: 0.8950 - val_loss: 0.4076 - val_accuracy: 0.8875
# Epoch 54/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3944 - accuracy: 0.8917 - val_loss: 0.5151 - val_accuracy: 0.8188
# Epoch 55/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.3951 - accuracy: 0.8925 - val_loss: 0.4222 - val_accuracy: 0.8792
# Epoch 56/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3808 - accuracy: 0.8950 - val_loss: 0.4166 - val_accuracy: 0.8687
# Epoch 57/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3797 - accuracy: 0.9004 - val_loss: 0.3883 - val_accuracy: 0.9000
# Epoch 58/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3859 - accuracy: 0.8971 - val_loss: 0.4294 - val_accuracy: 0.8646
# Epoch 59/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3782 - accuracy: 0.9021 - val_loss: 0.4065 - val_accuracy: 0.8771
# Epoch 60/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.3862 - accuracy: 0.8979 - val_loss: 0.4032 - val_accuracy: 0.8813
# Epoch 61/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3848 - accuracy: 0.8958 - val_loss: 0.4599 - val_accuracy: 0.8625
# Epoch 62/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3724 - accuracy: 0.9075 - val_loss: 0.4618 - val_accuracy: 0.8583
# Epoch 63/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3827 - accuracy: 0.8950 - val_loss: 0.4082 - val_accuracy: 0.8833
# Epoch 64/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.3631 - accuracy: 0.9062 - val_loss: 0.4202 - val_accuracy: 0.8729
# Epoch 65/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3741 - accuracy: 0.9004 - val_loss: 0.4106 - val_accuracy: 0.8792
# Epoch 66/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3593 - accuracy: 0.9112 - val_loss: 0.4402 - val_accuracy: 0.8500
# Epoch 67/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3661 - accuracy: 0.8996 - val_loss: 0.4222 - val_accuracy: 0.8854
# Epoch 68/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3651 - accuracy: 0.9067 - val_loss: 0.4413 - val_accuracy: 0.8667
# Epoch 69/100
# 75/75 [==============================] - 4s 57ms/step - loss: 0.3580 - accuracy: 0.9137 - val_loss: 0.4109 - val_accuracy: 0.8854
# Epoch 70/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3655 - accuracy: 0.9054 - val_loss: 0.3760 - val_accuracy: 0.8958
# Epoch 71/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3548 - accuracy: 0.9125 - val_loss: 0.3913 - val_accuracy: 0.8792
# Epoch 72/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3616 - accuracy: 0.9067 - val_loss: 0.5243 - val_accuracy: 0.8375
# Epoch 73/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3557 - accuracy: 0.9079 - val_loss: 0.4157 - val_accuracy: 0.8792
# Epoch 74/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.3590 - accuracy: 0.9104 - val_loss: 0.4166 - val_accuracy: 0.8687
# Epoch 75/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.3497 - accuracy: 0.9129 - val_loss: 0.4449 - val_accuracy: 0.8667
# Epoch 76/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3461 - accuracy: 0.9117 - val_loss: 0.4308 - val_accuracy: 0.8854
# Epoch 77/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3550 - accuracy: 0.9179 - val_loss: 0.3651 - val_accuracy: 0.9021
# Epoch 78/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.3578 - accuracy: 0.9054 - val_loss: 0.3512 - val_accuracy: 0.9042
# Epoch 79/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.3459 - accuracy: 0.9117 - val_loss: 0.5169 - val_accuracy: 0.8292
# Epoch 80/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3306 - accuracy: 0.9162 - val_loss: 0.3527 - val_accuracy: 0.9083
# Epoch 81/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3314 - accuracy: 0.9221 - val_loss: 0.3847 - val_accuracy: 0.8875
# Epoch 82/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3312 - accuracy: 0.9225 - val_loss: 0.4496 - val_accuracy: 0.8708
# Epoch 83/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3583 - accuracy: 0.9075 - val_loss: 0.3552 - val_accuracy: 0.8979
# Epoch 84/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3318 - accuracy: 0.9200 - val_loss: 0.3979 - val_accuracy: 0.8833
# Epoch 85/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3321 - accuracy: 0.9187 - val_loss: 0.4857 - val_accuracy: 0.8667
# Epoch 86/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.3342 - accuracy: 0.9221 - val_loss: 0.3527 - val_accuracy: 0.9083
# Epoch 87/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3218 - accuracy: 0.9204 - val_loss: 0.4645 - val_accuracy: 0.8646
# Epoch 88/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.3442 - accuracy: 0.9154 - val_loss: 0.3478 - val_accuracy: 0.9104
# Epoch 89/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3455 - accuracy: 0.9146 - val_loss: 0.5544 - val_accuracy: 0.8313
# Epoch 90/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3297 - accuracy: 0.9212 - val_loss: 0.3927 - val_accuracy: 0.8833
# Epoch 91/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.3264 - accuracy: 0.9192 - val_loss: 0.3727 - val_accuracy: 0.9125
# Epoch 92/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3211 - accuracy: 0.9242 - val_loss: 0.4629 - val_accuracy: 0.8562
# Epoch 93/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.3113 - accuracy: 0.9304 - val_loss: 0.3432 - val_accuracy: 0.9104
# Epoch 94/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.3346 - accuracy: 0.9183 - val_loss: 0.4003 - val_accuracy: 0.8896
# Epoch 95/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3280 - accuracy: 0.9204 - val_loss: 0.3495 - val_accuracy: 0.9083
# Epoch 96/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3193 - accuracy: 0.9258 - val_loss: 0.4001 - val_accuracy: 0.8833
# Epoch 97/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3348 - accuracy: 0.9183 - val_loss: 0.4004 - val_accuracy: 0.8854
# Epoch 98/100
# 75/75 [==============================] - 4s 56ms/step - loss: 0.3111 - accuracy: 0.9321 - val_loss: 0.3552 - val_accuracy: 0.9146
# Epoch 99/100
# 75/75 [==============================] - 4s 54ms/step - loss: 0.3205 - accuracy: 0.9258 - val_loss: 0.4146 - val_accuracy: 0.8833
# Epoch 100/100
# 75/75 [==============================] - 4s 55ms/step - loss: 0.3188 - accuracy: 0.9254 - val_loss: 0.4228 - val_accuracy: 0.8938

# %%
N = np.arange(0, epochs)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
