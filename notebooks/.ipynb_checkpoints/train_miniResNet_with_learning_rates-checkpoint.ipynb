# %% [markdown]
# ### Custom Shallow Network - MiniResNet with best learning rate

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext tensorboard

# %%
import os
import numpy as np
from glob import glob
from tqdm import tqdm
import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array, ImageDataGenerator
from tensorflow.keras.models import Model 
from tensorflow.keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.layers import Input, Activation, Dropout, Flatten, Dense, add
from tensorflow.keras.utils  import to_categorical
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
import matplotlib.pyplot as plt 

# %matplotlib inline

# %%
# dimensions of our images.
img_width, img_height = 224, 224

train_data_dir = '/home/sanchit/Documents/Projects/datasets/fire_and_smoke_data/train/'
validation_data_dir = '/home/sanchit/Documents/Projects/datasets/fire_and_smoke_data/val/'
nb_train_samples = 2400
nb_validation_samples = 490
epochs = 100
batch_size = 32
init_lr = 0.01

# %%
physical_devices = tf.config.list_physical_devices('GPU')
tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
class MiniResNet:
    """ mini version of ResNet architecture """
    
    def __init__(self, img_width, img_height):
        self.img_width = img_width
        self.img_height = img_height
        
    def __residual_block(self, x, filters, is_reduce_dim=False, reg=0.0001):
        shortcut = x 
        
        # pre-activation block, act1 goes as an input to conv1
        # first part of the block are 1x1 CONVs with 1/4th of original number of filters
        bn1 = BatchNormalization()(x)
        act1 = Activation("relu")(bn1)
        
        if is_reduce_dim:
            # convolve (1,1) on the input x which stays as a shortcut to incorporate reduction in dim 
            shortcut = Conv2D(filters, (1,1), strides=(2,2), use_bias=False, kernel_initializer='he_normal', 
                              padding="same", kernel_regularizer=l2(reg))(x)
            
            # first convolution on act1 
            conv1 = Conv2D(int(filters*0.25), (1,1), strides=(2,2), use_bias=False, kernel_initializer='he_normal', 
                           padding="same", kernel_regularizer=l2(reg))(act1)
            
        else:
            shortcut = Conv2D(filters, (1,1), use_bias=False, kernel_initializer='he_normal', 
                              padding="same", kernel_regularizer=l2(reg))(x)
            
            conv1 = Conv2D(int(filters*0.25), (1,1), use_bias=False, kernel_initializer='he_normal', 
                           padding="same", kernel_regularizer=l2(reg))(act1) 
        
        # second part of the block are 3x3 CONVs with 1/4th original number of filters
        bn2 = BatchNormalization()(conv1)
        act2 = Activation("relu")(bn2)
        conv2 = Conv2D(int(filters*0.25), (3,3), use_bias=False, kernel_initializer='he_normal', 
                       padding="same", kernel_regularizer=l2(reg))(act2)
        
        # third part of the block are 1x1 CONVs with original number of filters
        bn3 = BatchNormalization()(conv2)
        act3 = Activation("relu")(bn3)
        conv3 = Conv2D(filters, (1,1), use_bias=False, kernel_initializer='he_normal', 
                       padding="same", kernel_regularizer=l2(reg))(act3)
        
        # lastly add the shortcut and last output 
        out = add([shortcut, conv3])
        return out
        
    def build(self):
        
        input_img = Input(shape=(self.img_width, self.img_height, 3), name='input_image')
        
        x = Conv2D(16, kernel_size=(3, 3), strides=1, padding='same', 
                   kernel_initializer='he_normal', kernel_regularizer=l2(1e-4))(input_img)
        x = BatchNormalization()(x)
        x = Activation("relu")(x)
        
        x = self.__residual_block(x, 16, is_reduce_dim=False) # 224
        x = self.__residual_block(x, 16, is_reduce_dim=True) # 112 
        x = self.__residual_block(x, 16, is_reduce_dim=False) # 112
        
        x = self.__residual_block(x, 32, is_reduce_dim=True) # 56
        x = self.__residual_block(x, 32, is_reduce_dim=False) # 56
        
        x = self.__residual_block(x, 64, is_reduce_dim=True) # 28
        x = self.__residual_block(x, 64, is_reduce_dim=False) # 28
        
        x = self.__residual_block(x, 128, is_reduce_dim=True) # 14
        x = self.__residual_block(x, 128, is_reduce_dim=False) # 14
        
        x = self.__residual_block(x, 256, is_reduce_dim=True) # 7
        x = self.__residual_block(x, 256, is_reduce_dim=False) # 7
              
        x = BatchNormalization()(x)
        x = Activation("relu", name="last_conv_relu")(x)
        x = GlobalAveragePooling2D()(x)
            
        # classifier 
        x = Flatten()(x)
        x = Dense(64, kernel_regularizer=l2(1e-4))(x)
        x = Activation("relu", name="last_relu")(x)
        x = Dense(1)(x)
        output = Activation("sigmoid")(x)
        
        model = Model(inputs=input_img, outputs=output)
        return model

# %%
miniResNet = MiniResNet(img_width, img_height)
model = miniResNet.build()

# opt = SGD(lr=init_lr, momentum=0.9) # 90%
#opt = SGD(lr=init_lr, momentum=0.9, decay=init_lr/epochs) # 91.50 %
opt = Adam() # 92.92 %
#opt = RMSprop() # 92.9 %
opt = Adam(learning_rate=init_lr) # 81 %
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# model.compile(loss='binary_crossentropy',
#               optimizer='rmsprop',
#               metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_image (InputLayer)        [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 224, 224, 16) 448         input_image[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 224, 224, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 224, 224, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 16) 64          activation[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 16) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 4)  64          activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 4)  16          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 4)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 224, 224, 4)  144         activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 224, 224, 4)  16          conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 224, 224, 4)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 16) 256         activation[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 224, 224, 16) 64          activation_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 224, 224, 16) 0           conv2d_1[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 224, 224, 16) 64          add[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 224, 224, 16) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 112, 112, 4)  64          activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 112, 112, 4)  16          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 112, 112, 4)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 112, 112, 4)  144         activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 112, 112, 4)  16          conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 112, 112, 4)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 112, 112, 16) 256         add[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 112, 112, 16) 64          activation_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 112, 112, 16) 0           conv2d_5[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 112, 112, 16) 64          add_1[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 112, 112, 16) 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 112, 112, 4)  64          activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 112, 112, 4)  16          conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 112, 112, 4)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 112, 112, 4)  144         activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 112, 112, 4)  16          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 112, 112, 4)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 112, 112, 16) 256         add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 112, 112, 16) 64          activation_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 112, 112, 16) 0           conv2d_9[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 112, 112, 16) 64          add_2[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 112, 112, 16) 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 56, 56, 8)    128         activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 56, 56, 8)    32          conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 56, 56, 8)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 56, 56, 8)    576         activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 56, 56, 8)    32          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 56, 56, 8)    0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 56, 56, 32)   512         add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 56, 56, 32)   256         activation_12[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 56, 56, 32)   0           conv2d_13[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 56, 56, 32)   128         add_3[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 56, 56, 32)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 8)    256         activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 56, 56, 8)    32          conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 56, 56, 8)    0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 56, 56, 8)    576         activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 56, 56, 8)    32          conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 56, 56, 8)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 32)   1024        add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 56, 56, 32)   256         activation_15[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 56, 56, 32)   0           conv2d_17[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 56, 56, 32)   128         add_4[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 56, 56, 32)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 28, 28, 16)   512         activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 28, 28, 16)   64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 16)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 28, 28, 16)   2304        activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 28, 28, 16)   64          conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 16)   0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 28, 28, 64)   2048        add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 28, 28, 64)   1024        activation_18[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 64)   0           conv2d_21[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 28, 28, 64)   256         add_5[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 28, 28, 16)   1024        activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 28, 28, 16)   64          conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 16)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 28, 28, 16)   2304        activation_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 28, 28, 16)   64          conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 16)   0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 28, 28, 64)   4096        add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 28, 28, 64)   1024        activation_21[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 64)   0           conv2d_25[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 28, 28, 64)   256         add_6[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 32)   2048        activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 14, 14, 32)   128         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 32)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 32)   9216        activation_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 14, 14, 32)   128         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 32)   0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 128)  8192        add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 128)  4096        activation_24[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 128)  0           conv2d_29[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 14, 14, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 128)  0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 32)   4096        activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 14, 14, 32)   128         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 32)   9216        activation_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 14, 14, 32)   128         conv2d_35[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 32)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 128)  16384       add_7[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 128)  4096        activation_27[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 128)  0           conv2d_33[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 14, 14, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 7, 7, 64)     8192        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 7, 7, 64)     256         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 7, 7, 64)     0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 7, 7, 64)     36864       activation_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 7, 7, 64)     256         conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 7, 7, 64)     0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 7, 7, 256)    32768       add_8[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 7, 7, 256)    16384       activation_30[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 7, 7, 256)    0           conv2d_37[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 7, 7, 256)    1024        add_9[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 7, 7, 256)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 7, 7, 64)     16384       activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 7, 7, 64)     256         conv2d_42[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 7, 7, 64)     0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 7, 7, 64)     36864       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 7, 7, 64)     256         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 7, 7, 64)     0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 7, 7, 256)    65536       add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 7, 7, 256)    16384       activation_33[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 7, 7, 256)    0           conv2d_41[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 7, 7, 256)    1024        add_10[0][0]
# __________________________________________________________________________________________________
# last_conv_relu (Activation)     (None, 7, 7, 256)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 256)          0           last_conv_relu[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 64)           16448       flatten[0][0]
# __________________________________________________________________________________________________
# last_relu (Activation)          (None, 64)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1)            65          last_relu[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 1)            0           dense_1[0][0]
# ==================================================================================================
# Total params: 329,361
# Trainable params: 326,273
# Non-trainable params: 3,088
# __________________________________________________________________________________________________

# %%
def load_data(dir_path="", class_mode='binary', classes=None):
    """
    loads all the images for all the classes (sub-dirs) provided in the input directory.
    :param dir_path -  input directory which contains for each class a sub-directory. 
    :param class_mode - binary (for usage in binary_crossentropy loss) and categorical (categorical_crossentropy loss)
    :params classes - a list of classes'names 
    """
    X = []
    y = []
    data_kind = dir_path.split("/")[-2] # either training or validation or testing
    directories=[d for d in os.listdir(dir_path) if os.path.isdir(d) or (not d.startswith("."))]
    
    for label, class_name in enumerate(directories):
        print(f"loading {data_kind} data for class: {class_name}")
        class_dir = os.path.join(dir_path, class_name)
        for img_path in tqdm(glob(class_dir + '/*.jpg')):
            img = load_img(img_path, target_size=(img_width, img_height))
            img = img_to_array(img)

            # save the image and its corresponding label
            X.append(img)
            y.append(label)
                
    X = np.asarray(X, dtype=np.float32) / 255.0
    y = np.asarray(y)
    
    if class_mode == "categorical":
        y = to_categorical(y_train, num_classes=classes)
        
    print(f"total number of images loaded: {X.shape[0]} and of shape: {X.shape[1:]}")
    
    return X, y

# %%
X_train, y_train = load_data(dir_path=train_data_dir)
X_val, y_val = load_data(dir_path=validation_data_dir)
# Out:
#   2%|▏         | 21/1200 [00:00<00:05, 209.38it/s]
# loading train data for class: fire
#  35%|███▌      | 424/1200 [00:03<00:05, 133.17it/s]/home/sanchit/miniconda3/envs/tf2.1/lib/python3.7/site-packages/PIL/Image.py:932: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# 100%|██████████| 1200/1200 [00:09<00:00, 123.65it/s]
#   2%|▏         | 21/1200 [00:00<00:06, 184.88it/s]
# loading train data for class: no_fire
# 100%|██████████| 1200/1200 [00:09<00:00, 126.51it/s]
#   3%|▎         | 7/245 [00:00<00:06, 36.29it/s]
# total number of images loaded: 2400 and of shape: (224, 224, 3)
# loading val data for class: fire
# 100%|██████████| 245/245 [00:03<00:00, 72.99it/s]
#  12%|█▏        | 30/245 [00:00<00:00, 281.69it/s]
# loading val data for class: no_fire
# 100%|██████████| 245/245 [00:01<00:00, 136.99it/s]
# total number of images loaded: 490 and of shape: (224, 224, 3)

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# create a train generator
train_datagen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True, 
    vertical_flip=True,
    rotation_range=30,
    fill_mode="wrap",
    height_shift_range=0.15,
    width_shift_range=0.15)

# preprocessing_function=get_random_eraser(v_l=0, v_h=1)

# create a test/val generator
test_datagen = ImageDataGenerator()

# %%
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size, shuffle=True)

validation_generator = test_datagen.flow(X_val, y_val, batch_size=batch_size, shuffle=False)

# %%
H = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size, 
    workers = 8)
# Out:
# WARNING:tensorflow:From <ipython-input-13-8932531e58bf>:7: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 75 steps, validate for 15 steps
# Epoch 1/100
# 75/75 [==============================] - 10s 133ms/step - loss: 0.9301 - accuracy: 0.6562 - val_loss: 0.8551 - val_accuracy: 0.5104
# Epoch 2/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.6999 - accuracy: 0.7033 - val_loss: 0.7687 - val_accuracy: 0.5104
# Epoch 3/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.6105 - accuracy: 0.7342 - val_loss: 0.7512 - val_accuracy: 0.5104
# Epoch 4/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.6034 - accuracy: 0.7383 - val_loss: 0.8051 - val_accuracy: 0.6521
# Epoch 5/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.6164 - accuracy: 0.7375 - val_loss: 0.7261 - val_accuracy: 0.5562
# Epoch 6/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.6003 - accuracy: 0.7400 - val_loss: 1.4282 - val_accuracy: 0.5104
# Epoch 7/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.6312 - accuracy: 0.7371 - val_loss: 0.7795 - val_accuracy: 0.6687
# Epoch 8/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.5853 - accuracy: 0.7479 - val_loss: 0.7592 - val_accuracy: 0.5188
# Epoch 9/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.
100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.4375 - accuracy: 0.8621 - val_loss: 0.7013 - val_accuracy: 0.6750
# Epoch 72/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.4029 - accuracy: 0.8783 - val_loss: 0.7301 - val_accuracy: 0.6938
# Epoch 73/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.4150 - accuracy: 0.8687 - val_loss: 0.6193 - val_accuracy: 0.7229
# Epoch 74/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.4044 - accuracy: 0.8625 - val_loss: 0.5412 - val_accuracy: 0.7750
# Epoch 75/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.4118 - accuracy: 0.8642 - val_loss: 0.8323 - val_accuracy: 0.5917
# Epoch 76/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3961 - accuracy: 0.8696 - val_loss: 0.6266 - val_accuracy: 0.7417
# Epoch 77/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3920 - accuracy: 0.8742 - val_loss: 0.6263 - val_accuracy: 0.7354
# Epoch 78/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.3889 - accuracy: 0.8700 - val_loss: 0.5852 - val_accuracy: 0.7375
# Epoch 79/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.3951 - accuracy: 0.8692 - val_loss: 0.6684 - val_accuracy: 0.6333
# Epoch 80/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.3911 - accuracy: 0.8729 - val_loss: 0.6467 - val_accuracy: 0.6896
# Epoch 81/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3817 - accuracy: 0.8754 - val_loss: 0.7095 - val_accuracy: 0.7125
# Epoch 82/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3717 - accuracy: 0.8783 - val_loss: 0.4360 - val_accuracy: 0.8208
# Epoch 83/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3738 - accuracy: 0.8763 - val_loss: 1.0820 - val_accuracy: 0.6042
# Epoch 84/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3815 - accuracy: 0.8679 - val_loss: 0.9320 - val_accuracy: 0.6708
# Epoch 85/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3879 - accuracy: 0.8687 - val_loss: 0.7300 - val_accuracy: 0.7208
# Epoch 86/100
# 75/75 [==============================] - 6s 73ms/step - loss: 0.3807 - accuracy: 0.8717 - val_loss: 1.9339 - val_accuracy: 0.6687
# Epoch 87/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3657 - accuracy: 0.8804 - val_loss: 0.7198 - val_accuracy: 0.7333
# Epoch 88/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.3952 - accuracy: 0.8667 - val_loss: 0.5309 - val_accuracy: 0.7542
# Epoch 89/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3717 - accuracy: 0.8692 - val_loss: 0.5755 - val_accuracy: 0.7375
# Epoch 90/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3750 - accuracy: 0.8671 - val_loss: 0.6583 - val_accuracy: 0.7146
# Epoch 91/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.3882 - accuracy: 0.8642 - val_loss: 0.4578 - val_accuracy: 0.8438
# Epoch 92/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.5263 - accuracy: 0.8392 - val_loss: 0.9037 - val_accuracy: 0.7333
# Epoch 93/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.5096 - accuracy: 0.8571 - val_loss: 0.6371 - val_accuracy: 0.7625
# Epoch 94/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.4387 - accuracy: 0.8633 - val_loss: 0.5685 - val_accuracy: 0.7708
# Epoch 95/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.4026 - accuracy: 0.8829 - val_loss: 0.7479 - val_accuracy: 0.6187
# Epoch 96/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.4182 - accuracy: 0.8658 - val_loss: 0.7647 - val_accuracy: 0.5646
# Epoch 97/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.4037 - accuracy: 0.8712 - val_loss: 0.7535 - val_accuracy: 0.5500
# Epoch 98/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.4055 - accuracy: 0.8650 - val_loss: 0.7349 - val_accuracy: 0.5979
# Epoch 99/100
# 75/75 [==============================] - 5s 72ms/step - loss: 0.3897 - accuracy: 0.8700 - val_loss: 0.7345 - val_accuracy: 0.5708
# Epoch 100/100
# 75/75 [==============================] - 5s 73ms/step - loss: 0.3643 - accuracy: 0.8858 - val_loss: 0.4914 - val_accuracy: 0.7958

# %%
N = np.arange(0, epochs)
plt.style.use("ggplot")
plt.figure()
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("Training Loss and Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Loss/Accuracy")
plt.legend()
plt.show()
